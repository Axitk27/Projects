# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
with open('phone.html',encoding = "utf-8") as f:
    html = f.read()

# %%
soup = BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder sm-smc-in" lang="en" style="--window-width: 1536;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#0a3a75" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="en_IN" property="og:locale"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"Organization","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","logo":"https://www.smartprix.com/smartprix.png","sameAs":["https://www.facebook.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://www.pinterest.com/smartprixcom/","https://x.com/smartprix","https://t.me/Smartprix_Deals","https://news.google.com/publications/CAAqBwgKMKe7jwswjemiAw","https://whatsapp.com/channel/0029Va91m7GAjPXHDPpBfW2o"]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"Website","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"Oppo K13 Turbo Pro","url":"https://www.smartprix.com/mobiles/oppo-k13-turbo-pro-ppd1rubxxjhp","image":["https://cdn1.smartprix.com/rx-i9N8A9cWD-w1200-h1200/9N8A9cWD.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"Vivo V60 5G","url":"https://www.smartprix.com/mobiles/vivo-v60-5g-ppd1tkery1ow","image":["https://cdn1.smartprix.com/rx-i9CFhTDbD-w1200-h1200/9CFhTDbD.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Motorola Moto G86 Power 5G","url":"https://www.smartprix.com/mobiles/motorola-moto-g86-power-ppd1xdleoq66","image":["https://cdn1.smartprix.com/rx-i8cGg6f7L-w1200-h1200/8cGg6f7L.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Xiaomi Redmi Note 14 SE 5G","url":"https://www.smartprix.com/mobiles/xiaomi-redmi-note-14-se-5g-ppd1ay1il4w5","image":["https://cdn1.smartprix.com/rx-i7a47upQu-w1200-h1200/7a47upQu.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"OnePlus Nord CE 5 5G","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-5-5g-ppd1r3kavvs1","image":["https://cdn1.smartprix.com/rx-irxQnFE3b-w1200-h1200/rxQnFE3b.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Vivo T4R 5G","url":"https://www.smartprix.com/mobiles/vivo-t4r-5g-ppd1lmovzrv3","image":["https://cdn1.smartprix.com/rx-i0GKXd2rl-w1200-h1200/0GKXd2rl.webp"]},{"@ ...

# %%
phone = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        prices.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                                model    price rating  \
# 0                 Oppo K13 Turbo Pro  ₹37,999    NaN
# 1         Motorola Moto G86 Power 5G  ₹17,999    NaN
# 2         Xiaomi Redmi Note 14 SE 5G  ₹14,999    NaN
# 3               OnePlus Nord CE 5 5G  ₹24,998    NaN
# 4                        Vivo T4R 5G  ₹19,499    NaN
# ...                              ...      ...    ...
# 1013  iQOO Z6 Lite (6GB RAM + 128GB)  ₹13,999     77
# 1014    Apple iPhone 14 Plus (256GB)  ₹79,900    NaN
# 1015     OPPO A77 (4GB RAM + 128 GB)  ₹10,590     70
# 1016                       OPPO A17K   ₹8,499     61
# 1017                        OPPO A17   ₹9,999     71
#
#                                                     sim  \
# 0        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 4              Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# ...                                                 ...
# 1013                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1016                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1017                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                               processor  \
# 0      Snapdragon 8s Gen4, Octa Core, 3.2 GHz Processor
# 1          Dimensity 7400, Octa Core, 2.6 GHz Processor
# 2     Dimensity 7025 Ultra, Octa Core, 2.5 GHz Proce...
# 3     Dimensity 8350 Apex, Octa Core, 3.35 GHz Proce...
# 4          Dimensity 7400, Octa Core, 2.6 GHz Processor
# ...                                                 ...
# 1013    Snapdragon  4 Gen 1, Octa Core, 2 GHz Processor
# 1014          Bionic A15, Hexa Core, 3.22 GHz Processor
# 1015            Helio G35, Octa Core, 2.3 GHz Processor
# 1016            Helio G35, Octa Core, 2.3 GHz Processor
# 1017            Helio G35, Octa Core, 2.3 GHz Processor
#
#                            ram                                  battery  \
# 0     8 GB RAM, 256 GB inbuilt  7000 mAh Battery with 80W Fast Charging
# 1     8 GB RAM, 128 GB inbuilt  6720 mAh Battery with 30W Fast Charging
# 2     6 GB RAM, 128 GB inbuilt  5110 mAh Battery with 45W Fast Charging
# 3     8 GB RAM, 128 GB inbuilt  7100 mAh Battery with 80W Fast Charging
# 4     8 GB RAM, 128 GB inbuilt  5700 mAh Battery with 44W Fast Charging
# ...                        ...                                      ...
# 1013  6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 1014  6 GB RAM, 256 GB inbuilt      4325 mAh Battery with Fast Charging
# 1015  4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 33W Fast Charging
# 1016   3 GB RAM, 64 GB inbuilt                         5000 mAh Battery
# 1017   4 GB RAM, 64 GB inbuilt      5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.8 inches, 1280 x 2800 px, 120 Hz Display wit...
# 1     6.7 inches, 1220 x 2712 px, 120 Hz Display wit...
# 2     6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 3     6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 4     6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# ...                                                 ...
# 1013  6.58 inches, 1080 x 2408 px, 120 Hz Display wi...
# 1014  6.7 inches, 1284 x 2778 px Display with Small ...
# 1015  6.56 inches, 720 x 1600 px Display with Water ...
# 1016  6.56 inches, 720 x 1612 px Display with Water ...
# 1017  6.56 inches, 720 x 1612 px Display with Water ...
#
#                                                  camera  \
# 0           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 1           50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 2     50 MP + 8 MP + 2 MP Triple Rear & 20 MP Front ...
# 3           50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 4           50 MP + 2 MP Dual Rear & 32 MP Front Camera
# ...                                                 ...
# 1013         50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 1014       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1015                50 MP Dual Rear & 8 MP Front Camera
# 1016                      8 MP Rear & 5 MP Front Camera
# 1017         50 MP + 2 MP Dual Rear & 5 MP Front Camera
#
#                                   card           os
# 0            Memory Card Not Supported  Android v15
# 1      Memory Card (Hybrid), upto 1 TB  Android v15
# 2      Memory Card (Hybrid), upto 1 TB  Android v15
# 3      Memory Card (Hybrid), upto 1 TB  Android v15
# 4            Memory Card Not Supported  Android v15
# ...                                ...          ...
# 1013   Memory Card (Hybrid), upto 1 TB  Android v12
# 1014         Memory Card Not Supported      iOS v16
# 1015             Memory Card Supported  Android v12
# 1016  Memory Card Supported, upto 1 TB  Android v12
# 1017  Memory Card Supported, upto 1 TB  Android v12
#
# [1018 rows x 11 columns]
